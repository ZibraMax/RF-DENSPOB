# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

import locale
locale.setlocale(locale.LC_ALL, 'de_DE.utf-8')
import matplotlib as mpl
mpl.rcParams['axes.formatter.use_locale'] = True

# %%
# !pip install pandas --user
# !pip install matplotlib --user
# !pip install numpy --user
# Out:
# ...
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# WARNING: You are using pip version 20.1.1; however, version 20.2.1 is available.
# You should consider upgrading via the 'c:\program files\python37\python.exe -m pip install --upgrade pip' command.

# %%
COLOR_ALTO = (237,248,177)
COLOR_MEDIO = (127,205,187)
COLOR_BAJO =(44,127,184)


#No modificar
color_parser = lambda x: x/255

COLOR_ALTO = list(map(color_parser,COLOR_ALTO))
COLOR_MEDIO = list(map(color_parser,COLOR_MEDIO))
COLOR_BAJO = list(map(color_parser,COLOR_BAJO))

# %% [markdown]
# # Graficas de validacíon de RF

# %% [markdown]
# ## Importancia

# %%
DATA = np.array([['CBD',0.9292],['Land Value',0.8904],['SES',0.5058],['MTFR',1],['MRN',0.5005],['MPTTS',0.4935],['HS',0.4845],['PP',0.5678],['ES',0.2969]])
DATA = np.array(sorted(DATA,key=lambda x: x[1]))
fig, ax = plt.subplots()
people = DATA[:,0]
y_pos = np.arange(len(people))

performance = DATA[:,1].astype(float)



ax.barh(y_pos, performance, align='center',color = COLOR_BAJO)
ax.set_yticks(y_pos)
ax.set_yticklabels(people)
ax.set_xlabel('Scaled Importance')
#ax.set_title('Variable Importance')
plt.savefig('Variable_Importance.svg') #NOMBRE DE ARCHIVO DE GUARDADO (USAR SVG PARA CALIDAD COMPLETA O PNG PARA CALIDAD NORMAL)

# %% [markdown]
# ## Numero de Árboles

# %%
porcentajes = [10,20,30,40,50]
data = []
fig, ax = plt.subplots()
for i in porcentajes:
    data.append(np.loadtxt(format(i)+'.txt'))
    ax.plot(data[-1][:,0],data[-1][:,1],label=format(i)+'%')
#plt.title('Sensitivity Iterations for Number of Trees')  #TITULO DE LA GRÁFICA
plt.xlabel('Number of Trees') #RÓTULO EJE X
plt.ylabel('R²') #RÓTULO EJE Y
ax.get_xaxis().set_major_formatter(matplotlib.ticker.FuncFormatter(lambda x, loc: locale.format('%d', x, 1)))
plt.legend(loc="upper right")
plt.savefig('Number_Trees.svg') #NOMBRE DE ARCHIVO DE GUARDADO (USAR SVG PARA CALIDAD COMPLETA O PNG PARA CALIDAD NORMAL)
# Out:
# c:\program files\python37\lib\site-packages\ipykernel_launcher.py:10: DeprecationWarning: This method will be removed in a future version of Python. Use 'locale.format_string()' instead.
#   # Remove the CWD from sys.path while we load stuff.

# %% [markdown]
# ## Validación

# %%
data = np.loadtxt('validation.csv',delimiter=',')
fig, ax = plt.subplots()

X = data[:,0]
Y = data[:,1]
TAMAÑO_PUNTO = [1]*len(X)
ax.scatter(X,Y,label='Data',s = TAMAÑO_PUNTO,color = COLOR_BAJO)
X = np.linspace(np.min(X),np.max(X),2)
m, b = [0.8103,120.61]
plt.plot(X, m*X + b,'--',color=(127/255,205/255,187/255),label='Lineal Regression: y = ' + format(m) + 'x + ' + format(b) + '\n' + r'R² = 0.9287')
#plt.title('SUR Random Forest Model Validation')  #TITULO DE LA GRÁFICA
plt.xlabel('Real Population Density') #RÓTULO EJE X
plt.ylabel('Predicted Population Density') #RÓTULO EJE Y
plt.legend()
ax.get_xaxis().set_major_formatter(matplotlib.ticker.FuncFormatter(lambda x, loc: locale.format('%d', x, 1)))
ax.get_yaxis().set_major_formatter(matplotlib.ticker.FuncFormatter(lambda x, loc: locale.format('%d', x, 1)))
plt.savefig('validation.svg') #NOMBRE DE ARCHIVO DE GUARDADO (USAR SVG PARA CALIDAD COMPLETA O PNG PARA CALIDAD NORMAL)
# Out:
# c:\program files\python37\lib\site-packages\ipykernel_launcher.py:15: DeprecationWarning: This method will be removed in a future version of Python. Use 'locale.format_string()' instead.
#   from ipykernel import kernelapp as app
# c:\program files\python37\lib\site-packages\ipykernel_launcher.py:16: DeprecationWarning: This method will be removed in a future version of Python. Use 'locale.format_string()' instead.
#   app.launch_new_instance()

# %% [markdown]
# # Histogramas

# %% [markdown]
# ## Densidad

# %% [markdown]
# ### ESCENARIO 1

# %%
bins = 50  #NUMERO DE BARRAS DEL HISTOGRAMA
FILE = 'E1.csv'  #ARCHIVO DE RESULTADOS
df = pd.read_csv(FILE)
cex = df['SES']=='ALTO'
cex1 = df['SES']=='MEDIO'
cex2 = df['SES']=='BAJO'

exx = df['DensPob_Pr'].values[cex]
exx1 = df['DensPob_Pr'].values[cex1]
exx2 = df['DensPob_Pr'].values[cex2]

DATA = np.array([exx,exx1,exx2])
labels = ['High','Medium','Low']  #LABELS DE LA LEYENDA
plt.hist(DATA, stacked=True,color=[COLOR_ALTO,COLOR_MEDIO,COLOR_BAJO],bins = int(bins),edgecolor = 'black',label=labels)



#plt.title('Histogram of Population Density for Scenario 1')  #TITULO DE LA GRÁFICA

ax = plt.gca()
ax.get_xaxis().set_major_formatter(matplotlib.ticker.FuncFormatter(lambda x, loc: locale.format('%d', x, 1)))
ax.get_yaxis().set_major_formatter(matplotlib.ticker.FuncFormatter(lambda x, loc: locale.format('%d', x, 1)))

plt.xlabel('Population Density [hab/ha]') #RÓTULO EJE X
plt.ylabel('Frequency') #RÓTULO EJE Y
plt.legend(loc="upper right")
plt.savefig('E1DENS.svg') #NOMBRE DE ARCHIVO DE GUARDADO (USAR SVG PARA CALIDAD COMPLETA O PNG PARA CALIDAD NORMAL)
# Out:
# c:\program files\python37\lib\site-packages\ipykernel_launcher.py:21: DeprecationWarning: This method will be removed in a future version of Python. Use 'locale.format_string()' instead.
# c:\program files\python37\lib\site-packages\ipykernel_launcher.py:22: DeprecationWarning: This method will be removed in a future version of Python. Use 'locale.format_string()' instead.

# %% [markdown]
# ### ESCENARIO 2

# %%
bins = 50  #NUMERO DE BARRAS DEL HISTOGRAMA
FILE = 'E2.csv'  #ARCHIVO DE RESULTADOS
df = pd.read_csv(FILE)
cex = df['SES']=='ALTO'
cex1 = df['SES']=='MEDIO'
cex2 = df['SES']=='BAJO'

exx = df['DensPob_Pr'].values[cex]
exx1 = df['DensPob_Pr'].values[cex1]
exx2 = df['DensPob_Pr'].values[cex2]

DATA = np.array([exx,exx1,exx2])
labels = ['High','Medium','Low']  #LABELS DE LA LEYENDA
plt.hist(DATA, stacked=True,color=[COLOR_ALTO,COLOR_MEDIO,COLOR_BAJO],bins = int(bins),edgecolor = 'black',label=labels)


ax = plt.gca()
ax.get_xaxis().set_major_formatter(matplotlib.ticker.FuncFormatter(lambda x, loc: locale.format('%d', x, 1)))
ax.get_yaxis().set_major_formatter(matplotlib.ticker.FuncFormatter(lambda x, loc: locale.format('%d', x, 1)))
#plt.title('Histogram of Population Density for Scenario 2')  #TITULO DE LA GRÁFICA


plt.xlabel('Population Density [hab/ha]') #RÓTULO EJE X
plt.ylabel('Frequency') #RÓTULO EJE Y
plt.legend(loc="upper right")
plt.savefig('E2DENS.svg') #NOMBRE DE ARCHIVO DE GUARDADO (USAR SVG PARA CALIDAD COMPLETA O PNG PARA CALIDAD NORMAL)
# Out:
# c:\program files\python37\lib\site-packages\ipykernel_launcher.py:18: DeprecationWarning: This method will be removed in a future version of Python. Use 'locale.format_string()' instead.
# c:\program files\python37\lib\site-packages\ipykernel_launcher.py:19: DeprecationWarning: This method will be removed in a future version of Python. Use 'locale.format_string()' instead.

# %% [markdown]
# ## Viajes

# %%
bins = 50 #NUMERO DE BARRAS DEL HISTOGRAMA
df = pd.read_csv('E1.csv') #ARCHIVO DE RESULTADOS
cex = df['SES']=='ALTO'
cex1 = df['SES']=='MEDIO'
cex2 = df['SES']=='BAJO'

exx = df['VAIAJES'].values[cex]
exx1 = df['VAIAJES'].values[cex1]
exx2 = df['VAIAJES'].values[cex2]
DATA = np.array([exx,exx1,exx2])
labels = ['High','Medium','Low'] #LABELS DE LA LEYENDA
plt.hist(DATA, stacked=True,color=[COLOR_ALTO,COLOR_MEDIO,COLOR_BAJO],bins = int(bins),edgecolor = 'black',label=labels)
#plt.title('Histogram of Trips for Scenario 1') #TITULO DE LA GRÁFICA
ax = plt.gca()
ax.get_xaxis().set_major_formatter(matplotlib.ticker.FuncFormatter(lambda x, loc: locale.format('%d', x, 1)))
ax.get_yaxis().set_major_formatter(matplotlib.ticker.FuncFormatter(lambda x, loc: locale.format('%d', x, 1)))
plt.xlabel('Trips [Trip/Block]') #RÓTULO EJE X

plt.ylabel('Frequency') #RÓTULO EJE Y

plt.legend(loc="upper right")

plt.savefig('E1TRIPS.svg') #NOMBRE DE ARCHIVO DE GUARDADO (USAR SVG PARA CALIDAD COMPLETA O PNG PARA CALIDAD NORMAL)
# Out:
# c:\program files\python37\lib\site-packages\ipykernel_launcher.py:15: DeprecationWarning: This method will be removed in a future version of Python. Use 'locale.format_string()' instead.
#   from ipykernel import kernelapp as app
# c:\program files\python37\lib\site-packages\ipykernel_launcher.py:16: DeprecationWarning: This method will be removed in a future version of Python. Use 'locale.format_string()' instead.
#   app.launch_new_instance()

# %%
bins = 50 #NUMERO DE BARRAS DEL HISTOGRAMA
df = pd.read_csv('E2.csv') #ARCHIVO DE RESULTADOS
cex = df['SES']=='ALTO'
cex1 = df['SES']=='MEDIO'
cex2 = df['SES']=='BAJO'

exx = df['VAIAJES'].values[cex]
exx1 = df['VAIAJES'].values[cex1]
exx2 = df['VAIAJES'].values[cex2]
DATA = np.array([exx,exx1,exx2])
labels = ['High','Medium','Low'] #LABELS DE LA LEYENDA
plt.hist(DATA, stacked=True,color=[COLOR_ALTO,COLOR_MEDIO,COLOR_BAJO],bins = int(bins),edgecolor = 'black',label=labels)
#plt.title('Histogram of Trips for Scenario 2') #TITULO DE LA GRÁFICA

plt.xlabel('Trips [Trip/Block]') #RÓTULO EJE X
ax = plt.gca()
ax.get_xaxis().set_major_formatter(matplotlib.ticker.FuncFormatter(lambda x, loc: locale.format('%d', x, 1)))
ax.get_yaxis().set_major_formatter(matplotlib.ticker.FuncFormatter(lambda x, loc: locale.format('%d', x, 1)))
plt.ylabel('Frequency') #RÓTULO EJE Y

plt.legend(loc="upper right")

plt.savefig('E2TRIPS.svg') #NOMBRE DE ARCHIVO DE GUARDADO (USAR SVG PARA CALIDAD COMPLETA O PNG PARA CALIDAD NORMAL)
# Out:
# c:\program files\python37\lib\site-packages\ipykernel_launcher.py:17: DeprecationWarning: This method will be removed in a future version of Python. Use 'locale.format_string()' instead.
# c:\program files\python37\lib\site-packages\ipykernel_launcher.py:18: DeprecationWarning: This method will be removed in a future version of Python. Use 'locale.format_string()' instead.
